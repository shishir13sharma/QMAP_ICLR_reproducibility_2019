# %%
from baselines.common import set_global_seeds
from baselines.common.misc_util import boolean_flag
from baselines.common.schedules import LinearSchedule

import argparse
import scipy.misc
import os, datetime, time, re
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np

import gym
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline
from copy import deepcopy
from agents.models_pytorch import dqn_model, qmap_model
from agents.q_map_dqn_agent_pytorch import Q_Map_DQN_Agent

from agents.replay_buffers import DoublePrioritizedReplayBuffer
from envs.custom_mario import CustomSuperMarioAllStarsEnv
from envs.wrappers import PerfLogger
from time import gmtime, strftime
# Out:
# Logging to /tmp/openai-2019-01-07-04-22-34-314811

# %%
# sys.argv = []
parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
parser.add_argument('--seed', help='random number generator seed', type=int, default=0)
parser.add_argument('--path', default='pytorch_results/' + strftime("%d_%b_%Y_%H_%M_%S", gmtime()))
parser.add_argument('--level', help='game level', default='1.1')
parser.add_argument('--load', help='steps of the models saved in Models folder', default=None)
boolean_flag(parser, 'dqn', default=True)
boolean_flag(parser, 'qmap', default=True)
boolean_flag(parser, 'render', help='play the videos', default=False)
args = parser.parse_args('')

# %%
env = CustomSuperMarioAllStarsEnv(screen_ratio=4, coords_ratio=8, use_color=False, use_rc_frame=False,
                                  stack=3, frame_skip=2, action_repeat=4, level=args.level)

coords_shape = env.coords_shape
set_global_seeds(args.seed)
env.seed(args.seed)
# Out:
# mario_level_1_1.state
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.uint8'>. Please provide explicit dtype.

# %%
mario_dqn = dqn_model(
        observation_space=env.observation_space.shape,
        conv_params=np.array([(32, 8, 2, 3), (32, 6, 2, 2), (64, 4, 2, 1)]),
        hidden_params=np.array([1024]),        
        layer_norm=True,
        activation_fn = F.relu,
        n_actions=env.action_space.n
    )

print(mario_dqn)
# Out:
# dqn_model(
#   (conv): ListModule(
#     (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(2, 2), padding=(3, 3))
#     (1): Conv2d(32, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (fc_action): ListModule(
#     (0): Linear(in_features=3584, out_features=1024, bias=True)
#     (1): Linear(in_features=1024, out_features=6, bias=True)
#   )
#   (fc_state): ListModule(
#     (0): Linear(in_features=3584, out_features=1024, bias=True)
#     (1): Linear(in_features=1024, out_features=1, bias=True)
#   )
#   (normalize_action): ListModule(
#     (0): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#   )
#   (normalize_state): ListModule(
#     (0): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
mario_qmap = qmap_model(
        observation_space=env.observation_space.shape,
        conv_params=np.array([(32, 8, 2, 3), (32, 6, 2, 2), (64, 4, 2, 1)]),
        hidden_params=np.array([1024]),
        deconv_params = np.array([(64, 4, 2, 1), (32, 6, 2, 2), (env.action_space.n, 4, 1, 2)]),
        layer_norm=True,
        activation_fn = F.elu,        
    )
print(mario_qmap)
# Out:
# qmap_model(
#   (conv): ListModule(
#     (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(2, 2), padding=(3, 3))
#     (1): Conv2d(32, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (fc): ListModule(
#     (0): Linear(in_features=3584, out_features=1024, bias=True)
#     (1): Linear(in_features=1024, out_features=3584, bias=True)
#   )
#   (normalize): ListModule(
#     (0): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#     (1): LayerNorm(torch.Size([3584]), eps=1e-05, elementwise_affine=True)
#   )
#   (deconv_action): ListModule(
#     (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ConvTranspose2d(64, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (2): ConvTranspose2d(32, 6, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
#   (deconv_state): ListModule(
#     (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ConvTranspose2d(64, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#     (2): ConvTranspose2d(32, 1, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   )
# )

# %%
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
mario_dqn = mario_dqn.to(device)
mario_qmap = mario_qmap.to(device)

n_steps = int(5e6)
exploration_schedule = LinearSchedule(schedule_timesteps=n_steps, initial_p=1.0, final_p=0.05)
q_map_random_schedule = LinearSchedule(schedule_timesteps=n_steps, initial_p=0.1, final_p=0.05)
double_replay_buffer = DoublePrioritizedReplayBuffer(int(5e5), alpha=0.6, epsilon=1e-6, 
                                                     timesteps=n_steps, initial_p=0.4, final_p=1.0)
task_gamma = 0.99
# Out:
# CUDA Available:  True

# %%
agent = Q_Map_DQN_Agent(    
    n_actions=env.action_space.n, 
    coords_shape=env.unwrapped.coords_shape,
    double_replay_buffer=double_replay_buffer,
    task_gamma=task_gamma,
    exploration_schedule=exploration_schedule,
    seed=args.seed,
    path=args.path,
    learning_starts=1000,
    train_freq=4,
    print_freq=1,    
    renderer_viewer=True,
    # DQN
    dqn_model= mario_dqn,
    dqn_lr=1e-4,
    dqn_optim_iters=1,
    dqn_batch_size=32,
    dqn_target_net_update_freq=1000,
    dqn_grad_norm_clip=1000,
    #QMAP
    q_map_model=mario_qmap,
    q_map_random_schedule=q_map_random_schedule,
    q_map_greedy_bias=0.5,
    q_map_timer_bonus=0.5, # 50% more time than predicted
    q_map_lr=3e-4,
    q_map_gamma=0.9,
    q_map_n_steps=1,
    q_map_batch_size=32,
    q_map_optim_iters=1,
    q_map_target_net_update_freq=1000,
    q_map_min_goal_steps=15,
    q_map_max_goal_steps=30,
    q_map_grad_norm_clip=1000
)
if args.load is not None:
    agent.load(args.path, args.load)
# Out:
# [CSVLogger] logging ['steps', 'planned exploration', 'current exploration', 'random actions', 'goal actions', 'greedy actions'] in pytorch_results/07_Jan_2019_04_22_34/exploration.csv

# %%
env = PerfLogger(env, agent.task_gamma, agent.path)
done = True
episode = 0
score = None
best_score = -1e6
best_distance = -1e6
previous_time = time.time()
last_ips_t = 0

for t in range(n_steps+1):        
    
    if done:
        new_best = False
        if episode > 0:
            if score >= best_score:
                best_score = score
                new_best = True
            distance = env.unwrapped.full_c
            if distance >= best_distance:
                best_distance = distance
                new_best = True

        if episode > 0 and (episode < 50 or episode % 10 == 0 or new_best):
            current_time = time.time()
            ips = (t - last_ips_t) / (current_time - previous_time)
            print('step: {} IPS: {:.2f}'.format(t+1, ips))
            name = 'score_%08.3f'%score + '_distance_' + str(distance) + '_steps_' + str(t+1) + '_episode_' + str(episode)                        
            agent.renderer.render(name)
            previous_time = current_time
            last_ips_t = t
        else:            
            agent.renderer.reset()
            
        episode += 1
        score = 0

        ob = env.reset()
        ac = agent.reset(ob)
        
    ob, rew, done, _ = env.step(ac)        
    score += rew                            
    
    ac = agent.step(ob, rew, done)    

env.close()
# Out:
# [CSVLogger] logging ['steps', 'undiscounted return', 'discounted return', 'episode length'] in pytorch_results/07_Jan_2019_04_22_34/score.csv
# step: 439 IPS: 46.65
# [renderer] preparing next video... 0 in the queue
# ---------------------------------------
# | episodes                | 1         |
# | exploration (current)   | 100.000 % |
# | exploration (target)    | 99.992 %  |
# | mean 100 episode reward | 0.000     |
# | steps                   | 438       |
# ---------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_104_steps_439_episode_1.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_104_steps_439_episode_1.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_104_steps_439_episode_1.npy
# step: 679 IPS: 30.73
# [renderer] preparing next video... 0 in the queue
# ---------------------------------------
# | episodes                | 2         |
# | exploration (current)   | 100.000 % |
# | exploration (target)    | 99.987 %  |
# | mean 100 episode reward | 0.000     |
# | steps                   | 678       |
# ---------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_182_steps_679_episode_2.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_182_steps_679_episode_2.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_182_steps_679_episode_2.npy
# step: 1087 IPS: 32.85
# [renderer] preparing next video... 0 in the queue
# ---------------------------------------
# | episodes                | 3         |
# | exploration (current)   | 100.000 % |
# | exploration (target)    | 99.979 %  |
# | mean 100 episode reward | 0.000     |
# | steps                   | 1086      |
# ---------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_169_steps_1087_episode_3.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_169_steps_1087_episode_3.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_169_steps_1087_episode_3.npy
# step: 1522 IPS: 20.45
# [renderer] preparing next video... 0 in the queue
# ---------------------------------------
# | episodes                | 4         |
# | exploration (current)   | 100.000 % |
# | exploration (target)    | 99.971 %  |
# | mean 100 episode reward | 0.000     |
# | steps                   | 1521      |
# ---------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_198_steps_1522_episode_4.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_198_steps_1522_episode_4.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_198_steps_1522_episode_4.npy
# step: 3939 IPS: 20.03
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 5        |
# | exploration (current)   | 98.611 % |
# | exploration (target)    | 99.925 % |
# | mean 100 episode reward | 3.300    |
# | steps                   | 3938     |
# --------------------------------------
# step: 4103 IPS: 12.66
# --------------------------------------
# | episodes                | 6        |
# | exploration (current)   | 98.530 % |
# | exploration (target)    | 99.922 % |
# | mean 100 episode reward | 2.750    |
# | steps                   | 4102     |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.500_distance_722_steps_3939_episode_5.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.500_distance_722_steps_3939_episode_5.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.500_distance_722_steps_3939_episode_5.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_285_steps_4103_episode_6.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_285_steps_4103_episode_6.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_285_steps_4103_episode_6.npy
# step: 5532 IPS: 18.37
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 7        |
# | exploration (current)   | 97.067 % |
# | exploration (target)    | 99.895 % |
# | mean 100 episode reward | 2.786    |
# | steps                   | 5531     |
# --------------------------------------
# step: 5704 IPS: 12.70
# --------------------------------------
# | episodes                | 8        |
# | exploration (current)   | 99.087 % |
# | exploration (target)    | 99.892 % |
# | mean 100 episode reward | 2.438    |
# | steps                   | 5703     |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0003.000_distance_644_steps_5532_episode_7.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0003.000_distance_644_steps_5532_episode_7.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0003.000_distance_644_steps_5532_episode_7.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_142_steps_5704_episode_8.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_142_steps_5704_episode_8.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_142_steps_5704_episode_8.npy
# step: 8026 IPS: 19.23
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 9        |
# | exploration (current)   | 98.335 % |
# | exploration (target)    | 99.848 % |
# | mean 100 episode reward | 2.500    |
# | steps                   | 8025     |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0003.000_distance_1119_steps_8026_episode_9.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0003.000_distance_1119_steps_8026_episode_9.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0003.000_distance_1119_steps_8026_episode_9.npy
# step: 10226 IPS: 18.23
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 10       |
# | exploration (current)   | 99.046 % |
# | exploration (target)    | 99.806 % |
# | mean 100 episode reward | 3.850    |
# | steps                   | 10225    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.000_distance_1116_steps_10226_episode_10.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.000_distance_1116_steps_10226_episode_10.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.000_distance_1116_steps_10226_episode_10.npy
# step: 11670 IPS: 17.49
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 11       |
# | exploration (current)   | 98.135 % |
# | exploration (target)    | 99.778 % |
# | mean 100 episode reward | 4.955    |
# | steps                   | 11669    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.000_distance_831_steps_11670_episode_11.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.000_distance_831_steps_11670_episode_11.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.000_distance_831_steps_11670_episode_11.npy
# step: 13197 IPS: 18.30
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 12       |
# | exploration (current)   | 98.389 % |
# | exploration (target)    | 99.749 % |
# | mean 100 episode reward | 5.458    |
# | steps                   | 13196    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0011.000_distance_857_steps_13197_episode_12.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0011.000_distance_857_steps_13197_episode_12.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0011.000_distance_857_steps_13197_episode_12.npy
# step: 15614 IPS: 18.72
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 13       |
# | exploration (current)   | 97.949 % |
# | exploration (target)    | 99.703 % |
# | mean 100 episode reward | 6.269    |
# | steps                   | 15613    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.000_distance_638_steps_15614_episode_13.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.000_distance_638_steps_15614_episode_13.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.000_distance_638_steps_15614_episode_13.npy
# step: 16023 IPS: 13.29
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 14       |
# | exploration (current)   | 97.044 % |
# | exploration (target)    | 99.696 % |
# | mean 100 episode reward | 5.964    |
# | steps                   | 16022    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_258_steps_16023_episode_14.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_258_steps_16023_episode_14.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_258_steps_16023_episode_14.npy
# step: 16974 IPS: 18.88
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 15       |
# | exploration (current)   | 98.060 % |
# | exploration (target)    | 99.678 % |
# | mean 100 episode reward | 5.767    |
# | steps                   | 16973    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0003.000_distance_805_steps_16974_episode_15.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0003.000_distance_805_steps_16974_episode_15.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0003.000_distance_805_steps_16974_episode_15.npy
# step: 17308 IPS: 15.77
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 16       |
# | exploration (current)   | 98.055 % |
# | exploration (target)    | 99.671 % |
# | mean 100 episode reward | 5.406    |
# | steps                   | 17307    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_100_steps_17308_episode_16.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_100_steps_17308_episode_16.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_100_steps_17308_episode_16.npy
# step: 17494 IPS: 16.97
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 17       |
# | exploration (current)   | 97.242 % |
# | exploration (target)    | 99.668 % |
# | mean 100 episode reward | 5.088    |
# | steps                   | 17493    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_289_steps_17494_episode_17.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_289_steps_17494_episode_17.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_289_steps_17494_episode_17.npy
# step: 17650 IPS: 16.28
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 18       |
# | exploration (current)   | 96.638 % |
# | exploration (target)    | 99.665 % |
# | mean 100 episode reward | 4.806    |
# | steps                   | 17649    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_220_steps_17650_episode_18.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_220_steps_17650_episode_18.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_220_steps_17650_episode_18.npy
# step: 20052 IPS: 19.50
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 19       |
# | exploration (current)   | 98.456 % |
# | exploration (target)    | 99.619 % |
# | mean 100 episode reward | 4.605    |
# | steps                   | 20051    |
# --------------------------------------
# step: 20172 IPS: 12.63
# --------------------------------------
# | episodes                | 20       |
# | exploration (current)   | 97.642 % |
# | exploration (target)    | 99.617 % |
# | mean 100 episode reward | 4.375    |
# | steps                   | 20171    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0001.000_distance_722_steps_20052_episode_19.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0001.000_distance_722_steps_20052_episode_19.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0001.000_distance_722_steps_20052_episode_19.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_177_steps_20172_episode_20.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_177_steps_20172_episode_20.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_177_steps_20172_episode_20.npy
# step: 22589 IPS: 18.82
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 21       |
# | exploration (current)   | 97.417 % |
# | exploration (target)    | 99.571 % |
# | mean 100 episode reward | 4.738    |
# | steps                   | 22588    |
# --------------------------------------
# step: 22780 IPS: 12.72
# --------------------------------------
# | episodes                | 22       |
# | exploration (current)   | 99.386 % |
# | exploration (target)    | 99.567 % |
# | mean 100 episode reward | 4.523    |
# | steps                   | 22779    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0012.000_distance_722_steps_22589_episode_21.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0012.000_distance_722_steps_22589_episode_21.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0012.000_distance_722_steps_22589_episode_21.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_156_steps_22780_episode_22.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_156_steps_22780_episode_22.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_156_steps_22780_episode_22.npy
# step: 23019 IPS: 14.22
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 23       |
# | exploration (current)   | 97.024 % |
# | exploration (target)    | 99.563 % |
# | mean 100 episode reward | 4.326    |
# | steps                   | 23018    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_128_steps_23019_episode_23.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_128_steps_23019_episode_23.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_128_steps_23019_episode_23.npy
# step: 23092 IPS: 15.50
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 24       |
# | exploration (current)   | 95.984 % |
# | exploration (target)    | 99.561 % |
# | mean 100 episode reward | 4.146    |
# | steps                   | 23091    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_272_steps_23092_episode_24.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_272_steps_23092_episode_24.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_272_steps_23092_episode_24.npy
# step: 25494 IPS: 19.72
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 25       |
# | exploration (current)   | 99.088 % |
# | exploration (target)    | 99.516 % |
# | mean 100 episode reward | 4.060    |
# | steps                   | 25493    |
# --------------------------------------
# step: 25556 IPS: 12.86
# --------------------------------------
# | episodes                | 26       |
# | exploration (current)   | 99.511 % |
# | exploration (target)    | 99.514 % |
# | mean 100 episode reward | 3.981    |
# | steps                   | 25555    |
# --------------------------------------
# step: 25669 IPS: 12.27
# --------------------------------------
# | episodes                | 27       |
# | exploration (current)   | 99.312 % |
# | exploration (target)    | 99.512 % |
# | mean 100 episode reward | 3.833    |
# | steps                   | 25668    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_740_steps_25494_episode_25.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_740_steps_25494_episode_25.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_740_steps_25494_episode_25.npy
# [renderer] preparing next video... 1 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_279_steps_25556_episode_26.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_279_steps_25556_episode_26.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_279_steps_25556_episode_26.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_166_steps_25669_episode_27.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_166_steps_25669_episode_27.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_166_steps_25669_episode_27.npy
# step: 26439 IPS: 17.37
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 28       |
# | exploration (current)   | 97.501 % |
# | exploration (target)    | 99.498 % |
# | mean 100 episode reward | 3.696    |
# | steps                   | 26438    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_89_steps_26439_episode_28.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_89_steps_26439_episode_28.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_89_steps_26439_episode_28.npy
# step: 28856 IPS: 19.41
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 29       |
# | exploration (current)   | 99.612 % |
# | exploration (target)    | 99.452 % |
# | mean 100 episode reward | 4.052    |
# | steps                   | 28855    |
# --------------------------------------
# step: 28908 IPS: 12.31
# --------------------------------------
# | episodes                | 30       |
# | exploration (current)   | 99.770 % |
# | exploration (target)    | 99.451 % |
# | mean 100 episode reward | 3.917    |
# | steps                   | 28907    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0014.000_distance_657_steps_28856_episode_29.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0014.000_distance_657_steps_28856_episode_29.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0014.000_distance_657_steps_28856_episode_29.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_288_steps_28908_episode_30.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_288_steps_28908_episode_30.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_288_steps_28908_episode_30.npy
# step: 31325 IPS: 18.48
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 31       |
# | exploration (current)   | 97.695 % |
# | exploration (target)    | 99.405 % |
# | mean 100 episode reward | 4.306    |
# | steps                   | 31324    |
# --------------------------------------
# step: 31466 IPS: 12.47
# --------------------------------------
# | episodes                | 32       |
# | exploration (current)   | 96.993 % |
# | exploration (target)    | 99.402 % |
# | mean 100 episode reward | 4.172    |
# | steps                   | 31465    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.000_distance_848_steps_31325_episode_31.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.000_distance_848_steps_31325_episode_31.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.000_distance_848_steps_31325_episode_31.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_156_steps_31466_episode_32.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_156_steps_31466_episode_32.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_156_steps_31466_episode_32.npy
# step: 31756 IPS: 14.04
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 33       |
# | exploration (current)   | 97.932 % |
# | exploration (target)    | 99.397 % |
# | mean 100 episode reward | 4.045    |
# | steps                   | 31755    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_216_steps_31756_episode_33.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_216_steps_31756_episode_33.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_216_steps_31756_episode_33.npy
# step: 31911 IPS: 16.76
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 34       |
# | exploration (current)   | 98.305 % |
# | exploration (target)    | 99.394 % |
# | mean 100 episode reward | 3.926    |
# | steps                   | 31910    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_285_steps_31911_episode_34.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_285_steps_31911_episode_34.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_285_steps_31911_episode_34.npy
# step: 32028 IPS: 17.21
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 35       |
# | exploration (current)   | 97.651 % |
# | exploration (target)    | 99.391 % |
# | mean 100 episode reward | 3.814    |
# | steps                   | 32027    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_266_steps_32028_episode_35.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_266_steps_32028_episode_35.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_266_steps_32028_episode_35.npy
# step: 32371 IPS: 18.75
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 36       |
# | exploration (current)   | 98.546 % |
# | exploration (target)    | 99.385 % |
# | mean 100 episode reward | 3.708    |
# | steps                   | 32370    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_144_steps_32371_episode_36.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_144_steps_32371_episode_36.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_144_steps_32371_episode_36.npy
# step: 32751 IPS: 18.38
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 37       |
# | exploration (current)   | 97.578 % |
# | exploration (target)    | 99.378 % |
# | mean 100 episode reward | 3.662    |
# | steps                   | 32750    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_264_steps_32751_episode_37.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_264_steps_32751_episode_37.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_264_steps_32751_episode_37.npy
# step: 35107 IPS: 19.63
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 38       |
# | exploration (current)   | 99.715 % |
# | exploration (target)    | 99.333 % |
# | mean 100 episode reward | 3.566    |
# | steps                   | 35106    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_722_steps_35107_episode_38.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_722_steps_35107_episode_38.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_722_steps_35107_episode_38.npy
# step: 36435 IPS: 17.41
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 39       |
# | exploration (current)   | 97.790 % |
# | exploration (target)    | 99.308 % |
# | mean 100 episode reward | 3.551    |
# | steps                   | 36434    |
# --------------------------------------
# step: 36547 IPS: 12.67
# --------------------------------------
# | episodes                | 40       |
# | exploration (current)   | 98.758 % |
# | exploration (target)    | 99.306 % |
# | mean 100 episode reward | 3.462    |
# | steps                   | 36546    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0003.000_distance_683_steps_36435_episode_39.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0003.000_distance_683_steps_36435_episode_39.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0003.000_distance_683_steps_36435_episode_39.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_190_steps_36547_episode_40.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_190_steps_36547_episode_40.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_190_steps_36547_episode_40.npy
# step: 38964 IPS: 19.17
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 41       |
# | exploration (current)   | 97.734 % |
# | exploration (target)    | 99.260 % |
# | mean 100 episode reward | 3.622    |
# | steps                   | 38963    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0010.000_distance_719_steps_38964_episode_41.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0010.000_distance_719_steps_38964_episode_41.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0010.000_distance_719_steps_38964_episode_41.npy
# step: 40689 IPS: 17.96
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 42       |
# | exploration (current)   | 98.757 % |
# | exploration (target)    | 99.227 % |
# | mean 100 episode reward | 3.607    |
# | steps                   | 40688    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0003.000_distance_768_steps_40689_episode_42.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0003.000_distance_768_steps_40689_episode_42.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0003.000_distance_768_steps_40689_episode_42.npy
# step: 43106 IPS: 18.73
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 43       |
# | exploration (current)   | 98.345 % |
# | exploration (target)    | 99.181 % |
# | mean 100 episode reward | 3.837    |
# | steps                   | 43105    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0013.500_distance_648_steps_43106_episode_43.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0013.500_distance_648_steps_43106_episode_43.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0013.500_distance_648_steps_43106_episode_43.npy
# step: 43603 IPS: 14.38
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 44       |
# | exploration (current)   | 98.951 % |
# | exploration (target)    | 99.172 % |
# | mean 100 episode reward | 3.750    |
# | steps                   | 43602    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_250_steps_43603_episode_44.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_250_steps_43603_episode_44.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_250_steps_43603_episode_44.npy
# step: 43708 IPS: 14.37
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 45       |
# | exploration (current)   | 99.011 % |
# | exploration (target)    | 99.170 % |
# | mean 100 episode reward | 3.667    |
# | steps                   | 43707    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_288_steps_43708_episode_45.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_288_steps_43708_episode_45.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_288_steps_43708_episode_45.npy
# step: 46110 IPS: 19.76
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 46       |
# | exploration (current)   | 99.581 % |
# | exploration (target)    | 99.124 % |
# | mean 100 episode reward | 3.696    |
# | steps                   | 46109    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0005.000_distance_696_steps_46110_episode_46.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0005.000_distance_696_steps_46110_episode_46.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0005.000_distance_696_steps_46110_episode_46.npy
# step: 48242 IPS: 18.28
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 47       |
# | exploration (current)   | 97.695 % |
# | exploration (target)    | 99.083 % |
# | mean 100 episode reward | 3.745    |
# | steps                   | 48241    |
# --------------------------------------
# step: 48385 IPS: 12.61
# --------------------------------------
# | episodes                | 48       |
# | exploration (current)   | 98.126 % |
# | exploration (target)    | 99.081 % |
# | mean 100 episode reward | 3.667    |
# | steps                   | 48384    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0006.000_distance_864_steps_48242_episode_47.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0006.000_distance_864_steps_48242_episode_47.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0006.000_distance_864_steps_48242_episode_47.npy
# [renderer] preparing next video... 0 in the queue
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_157_steps_48385_episode_48.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_157_steps_48385_episode_48.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_157_steps_48385_episode_48.npy
# step: 50802 IPS: 18.87
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 49       |
# | exploration (current)   | 99.022 % |
# | exploration (target)    | 99.035 % |
# | mean 100 episode reward | 3.949    |
# | steps                   | 50801    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0017.500_distance_897_steps_50802_episode_49.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0017.500_distance_897_steps_50802_episode_49.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0017.500_distance_897_steps_50802_episode_49.npy
# step: 53204 IPS: 18.39
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 50       |
# | exploration (current)   | 98.362 % |
# | exploration (target)    | 98.989 % |
# | mean 100 episode reward | 3.950    |
# | steps                   | 53203    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0004.000_distance_898_steps_53204_episode_50.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0004.000_distance_898_steps_53204_episode_50.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0004.000_distance_898_steps_53204_episode_50.npy
# --------------------------------------
# | episodes                | 51       |
# | exploration (current)   | 98.084 % |
# | exploration (target)    | 98.944 % |
# | mean 100 episode reward | 3.951    |
# | steps                   | 55605    |
# --------------------------------------
# --------------------------------------
# | episodes                | 52       |
# | exploration (current)   | 97.745 % |
# | exploration (target)    | 98.932 % |
# | mean 100 episode reward | 3.875    |
# | steps                   | 56191    |
# --------------------------------------
# --------------------------------------
# | episodes                | 53       |
# | exploration (current)   | 97.518 % |
# | exploration (target)    | 98.896 % |
# | mean 100 episode reward | 4.066    |
# | steps                   | 58121    |
# --------------------------------------
# step: 60539 IPS: 19.47
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 54       |
# | exploration (current)   | 99.599 % |
# | exploration (target)    | 98.850 % |
# | mean 100 episode reward | 4.324    |
# | steps                   | 60538    |
# --------------------------------------
# --------------------------------------
# | episodes                | 55       |
# | exploration (current)   | 97.909 % |
# | exploration (target)    | 98.846 % |
# | mean 100 episode reward | 4.245    |
# | steps                   | 60762    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0018.000_distance_781_steps_60539_episode_54.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0018.000_distance_781_steps_60539_episode_54.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0018.000_distance_781_steps_60539_episode_54.npy
# --------------------------------------
# | episodes                | 56       |
# | exploration (current)   | 99.002 % |
# | exploration (target)    | 98.834 % |
# | mean 100 episode reward | 4.188    |
# | steps                   | 61382    |
# --------------------------------------
# --------------------------------------
# | episodes                | 57       |
# | exploration (current)   | 99.522 % |
# | exploration (target)    | 98.824 % |
# | mean 100 episode reward | 4.114    |
# | steps                   | 61889    |
# --------------------------------------
# --------------------------------------
# | episodes                | 58       |
# | exploration (current)   | 98.736 % |
# | exploration (target)    | 98.823 % |
# | mean 100 episode reward | 4.043    |
# | steps                   | 61948    |
# --------------------------------------
# --------------------------------------
# | episodes                | 59       |
# | exploration (current)   | 97.613 % |
# | exploration (target)    | 98.777 % |
# | mean 100 episode reward | 4.025    |
# | steps                   | 64350    |
# --------------------------------------
# step: 66781 IPS: 19.21
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 60       |
# | exploration (current)   | 98.654 % |
# | exploration (target)    | 98.731 % |
# | mean 100 episode reward | 4.233    |
# | steps                   | 66780    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0016.500_distance_828_steps_66781_episode_60.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0016.500_distance_828_steps_66781_episode_60.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0016.500_distance_828_steps_66781_episode_60.npy
# --------------------------------------
# | episodes                | 61       |
# | exploration (current)   | 98.730 % |
# | exploration (target)    | 98.685 % |
# | mean 100 episode reward | 4.418    |
# | steps                   | 69197    |
# --------------------------------------
# --------------------------------------
# | episodes                | 62       |
# | exploration (current)   | 98.888 % |
# | exploration (target)    | 98.674 % |
# | mean 100 episode reward | 4.347    |
# | steps                   | 69769    |
# --------------------------------------
# --------------------------------------
# | episodes                | 63       |
# | exploration (current)   | 98.347 % |
# | exploration (target)    | 98.668 % |
# | mean 100 episode reward | 4.278    |
# | steps                   | 70084    |
# --------------------------------------
# --------------------------------------
# | episodes                | 64       |
# | exploration (current)   | 98.357 % |
# | exploration (target)    | 98.661 % |
# | mean 100 episode reward | 4.242    |
# | steps                   | 70488    |
# --------------------------------------
# --------------------------------------
# | episodes                | 65       |
# | exploration (current)   | 97.804 % |
# | exploration (target)    | 98.659 % |
# | mean 100 episode reward | 4.177    |
# | steps                   | 70584    |
# --------------------------------------
# --------------------------------------
# | episodes                | 66       |
# | exploration (current)   | 96.678 % |
# | exploration (target)    | 98.613 % |
# | mean 100 episode reward | 4.159    |
# | steps                   | 72986    |
# --------------------------------------
# --------------------------------------
# | episodes                | 67       |
# | exploration (current)   | 97.592 % |
# | exploration (target)    | 98.610 % |
# | mean 100 episode reward | 4.097    |
# | steps                   | 73154    |
# --------------------------------------
# --------------------------------------
# | episodes                | 68       |
# | exploration (current)   | 98.537 % |
# | exploration (target)    | 98.607 % |
# | mean 100 episode reward | 4.066    |
# | steps                   | 73318    |
# --------------------------------------
# --------------------------------------
# | episodes                | 69       |
# | exploration (current)   | 98.180 % |
# | exploration (target)    | 98.593 % |
# | mean 100 episode reward | 4.022    |
# | steps                   | 74069    |
# --------------------------------------
# step: 74413 IPS: 19.28
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 70       |
# | exploration (current)   | 99.293 % |
# | exploration (target)    | 98.586 % |
# | mean 100 episode reward | 3.993    |
# | steps                   | 74412    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_286_steps_74413_episode_70.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_286_steps_74413_episode_70.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_286_steps_74413_episode_70.npy
# --------------------------------------
# | episodes                | 71       |
# | exploration (current)   | 99.775 % |
# | exploration (target)    | 98.584 % |
# | mean 100 episode reward | 3.937    |
# | steps                   | 74526    |
# --------------------------------------
# --------------------------------------
# | episodes                | 72       |
# | exploration (current)   | 99.637 % |
# | exploration (target)    | 98.538 % |
# | mean 100 episode reward | 3.951    |
# | steps                   | 76928    |
# --------------------------------------
# --------------------------------------
# | episodes                | 73       |
# | exploration (current)   | 99.831 % |
# | exploration (target)    | 98.493 % |
# | mean 100 episode reward | 3.938    |
# | steps                   | 79330    |
# --------------------------------------
# --------------------------------------
# | episodes                | 74       |
# | exploration (current)   | 99.956 % |
# | exploration (target)    | 98.490 % |
# | mean 100 episode reward | 3.885    |
# | steps                   | 79464    |
# --------------------------------------
# --------------------------------------
# | episodes                | 75       |
# | exploration (current)   | 98.861 % |
# | exploration (target)    | 98.445 % |
# | mean 100 episode reward | 3.860    |
# | steps                   | 81866    |
# --------------------------------------
# --------------------------------------
# | episodes                | 76       |
# | exploration (current)   | 98.621 % |
# | exploration (target)    | 98.443 % |
# | mean 100 episode reward | 3.836    |
# | steps                   | 81938    |
# --------------------------------------
# --------------------------------------
# | episodes                | 77       |
# | exploration (current)   | 98.184 % |
# | exploration (target)    | 98.432 % |
# | mean 100 episode reward | 3.825    |
# | steps                   | 82515    |
# --------------------------------------
# --------------------------------------
# | episodes                | 78       |
# | exploration (current)   | 99.473 % |
# | exploration (target)    | 98.427 % |
# | mean 100 episode reward | 3.776    |
# | steps                   | 82794    |
# --------------------------------------
# --------------------------------------
# | episodes                | 79       |
# | exploration (current)   | 97.502 % |
# | exploration (target)    | 98.381 % |
# | mean 100 episode reward | 3.911    |
# | steps                   | 85211    |
# --------------------------------------
# step: 85652 IPS: 19.75
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 80       |
# | exploration (current)   | 97.678 % |
# | exploration (target)    | 98.373 % |
# | mean 100 episode reward | 3.862    |
# | steps                   | 85651    |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_154_steps_85652_episode_80.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_154_steps_85652_episode_80.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_154_steps_85652_episode_80.npy
# --------------------------------------
# | episodes                | 81       |
# | exploration (current)   | 99.132 % |
# | exploration (target)    | 98.369 % |
# | mean 100 episode reward | 3.815    |
# | steps                   | 85857    |
# --------------------------------------
# --------------------------------------
# | episodes                | 82       |
# | exploration (current)   | 99.637 % |
# | exploration (target)    | 98.323 % |
# | mean 100 episode reward | 3.829    |
# | steps                   | 88259    |
# --------------------------------------
# --------------------------------------
# | episodes                | 83       |
# | exploration (current)   | 98.904 % |
# | exploration (target)    | 98.282 % |
# | mean 100 episode reward | 3.807    |
# | steps                   | 90421    |
# --------------------------------------
# --------------------------------------
# | episodes                | 84       |
# | exploration (current)   | 97.408 % |
# | exploration (target)    | 98.266 % |
# | mean 100 episode reward | 3.798    |
# | steps                   | 91273    |
# --------------------------------------
# --------------------------------------
# | episodes                | 85       |
# | exploration (current)   | 98.224 % |
# | exploration (target)    | 98.264 % |
# | mean 100 episode reward | 3.753    |
# | steps                   | 91393    |
# --------------------------------------
# --------------------------------------
# | episodes                | 86       |
# | exploration (current)   | 99.524 % |
# | exploration (target)    | 98.261 % |
# | mean 100 episode reward | 3.709    |
# | steps                   | 91524    |
# --------------------------------------
# --------------------------------------
# | episodes                | 87       |
# | exploration (current)   | 98.614 % |
# | exploration (target)    | 98.218 % |
# | mean 100 episode reward | 3.724    |
# | steps                   | 93791    |
# --------------------------------------
# --------------------------------------
# | episodes                | 88       |
# | exploration (current)   | 98.262 % |
# | exploration (target)    | 98.217 % |
# | mean 100 episode reward | 3.682    |
# | steps                   | 93845    |
# --------------------------------------
# --------------------------------------
# ...
# --------------------------------------
# | episodes                | 322      |
# | exploration (current)   | 95.652 % |
# | exploration (target)    | 92.895 % |
# | mean 100 episode reward | 4.915    |
# | steps                   | 373942   |
# --------------------------------------
# --------------------------------------
# | episodes                | 323      |
# | exploration (current)   | 91.290 % |
# | exploration (target)    | 92.849 % |
# | mean 100 episode reward | 4.825    |
# | steps                   | 376344   |
# --------------------------------------
# --------------------------------------
# | episodes                | 324      |
# | exploration (current)   | 90.362 % |
# | exploration (target)    | 92.847 % |
# | mean 100 episode reward | 4.775    |
# | steps                   | 376463   |
# --------------------------------------
# --------------------------------------
# | episodes                | 325      |
# | exploration (current)   | 88.721 % |
# | exploration (target)    | 92.838 % |
# | mean 100 episode reward | 4.625    |
# | steps                   | 376923   |
# --------------------------------------
# --------------------------------------
# | episodes                | 326      |
# | exploration (current)   | 92.927 % |
# | exploration (target)    | 92.801 % |
# | mean 100 episode reward | 4.735    |
# | steps                   | 378890   |
# --------------------------------------
# --------------------------------------
# | episodes                | 327      |
# | exploration (current)   | 93.673 % |
# | exploration (target)    | 92.755 % |
# | mean 100 episode reward | 4.825    |
# | steps                   | 381292   |
# --------------------------------------
# --------------------------------------
# | episodes                | 328      |
# | exploration (current)   | 90.784 % |
# | exploration (target)    | 92.728 % |
# | mean 100 episode reward | 4.795    |
# | steps                   | 382756   |
# --------------------------------------
# --------------------------------------
# | episodes                | 329      |
# | exploration (current)   | 88.437 % |
# | exploration (target)    | 92.723 % |
# | mean 100 episode reward | 4.775    |
# | steps                   | 383010   |
# --------------------------------------
# step: 384635 IPS: 19.35
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 330      |
# | exploration (current)   | 88.589 % |
# | exploration (target)    | 92.692 % |
# | mean 100 episode reward | 4.965    |
# | steps                   | 384634   |
# --------------------------------------
# --------------------------------------
# | episodes                | 331      |
# | exploration (current)   | 91.816 % |
# | exploration (target)    | 92.689 % |
# | mean 100 episode reward | 4.915    |
# | steps                   | 384775   |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0019.000_distance_1117_steps_384635_episode_330.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0019.000_distance_1117_steps_384635_episode_330.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0019.000_distance_1117_steps_384635_episode_330.npy
# --------------------------------------
# | episodes                | 332      |
# | exploration (current)   | 87.459 % |
# | exploration (target)    | 92.643 % |
# | mean 100 episode reward | 5.060    |
# | steps                   | 387192   |
# --------------------------------------
# --------------------------------------
# | episodes                | 333      |
# | exploration (current)   | 82.959 % |
# | exploration (target)    | 92.630 % |
# | mean 100 episode reward | 5.060    |
# | steps                   | 387908   |
# --------------------------------------
# --------------------------------------
# | episodes                | 334      |
# | exploration (current)   | 85.739 % |
# | exploration (target)    | 92.584 % |
# | mean 100 episode reward | 5.090    |
# | steps                   | 390310   |
# --------------------------------------
# --------------------------------------
# | episodes                | 335      |
# | exploration (current)   | 80.972 % |
# | exploration (target)    | 92.566 % |
# | mean 100 episode reward | 4.965    |
# | steps                   | 391254   |
# --------------------------------------
# --------------------------------------
# | episodes                | 336      |
# | exploration (current)   | 88.493 % |
# | exploration (target)    | 92.547 % |
# | mean 100 episode reward | 4.955    |
# | steps                   | 392267   |
# --------------------------------------
# --------------------------------------
# | episodes                | 337      |
# | exploration (current)   | 87.017 % |
# | exploration (target)    | 92.536 % |
# | mean 100 episode reward | 4.795    |
# | steps                   | 392863   |
# --------------------------------------
# --------------------------------------
# | episodes                | 338      |
# | exploration (current)   | 87.309 % |
# | exploration (target)    | 92.529 % |
# | mean 100 episode reward | 4.615    |
# | steps                   | 393223   |
# --------------------------------------
# --------------------------------------
# | episodes                | 339      |
# | exploration (current)   | 89.798 % |
# | exploration (target)    | 92.522 % |
# | mean 100 episode reward | 4.575    |
# | steps                   | 393567   |
# --------------------------------------
# step: 393766 IPS: 19.34
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 340      |
# | exploration (current)   | 94.099 % |
# | exploration (target)    | 92.518 % |
# | mean 100 episode reward | 4.595    |
# | steps                   | 393765   |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0002.000_distance_259_steps_393766_episode_340.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0002.000_distance_259_steps_393766_episode_340.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0002.000_distance_259_steps_393766_episode_340.npy
# --------------------------------------
# | episodes                | 341      |
# | exploration (current)   | 92.787 % |
# | exploration (target)    | 92.513 % |
# | mean 100 episode reward | 4.555    |
# | steps                   | 394044   |
# --------------------------------------
# --------------------------------------
# | episodes                | 342      |
# | exploration (current)   | 89.117 % |
# | exploration (target)    | 92.485 % |
# | mean 100 episode reward | 4.560    |
# | steps                   | 395521   |
# --------------------------------------
# --------------------------------------
# | episodes                | 343      |
# | exploration (current)   | 90.933 % |
# | exploration (target)    | 92.482 % |
# | mean 100 episode reward | 4.540    |
# | steps                   | 395677   |
# --------------------------------------
# --------------------------------------
# | episodes                | 344      |
# | exploration (current)   | 86.381 % |
# | exploration (target)    | 92.461 % |
# | mean 100 episode reward | 4.695    |
# | steps                   | 396793   |
# --------------------------------------
# --------------------------------------
# | episodes                | 345      |
# | exploration (current)   | 94.657 % |
# | exploration (target)    | 92.458 % |
# | mean 100 episode reward | 4.695    |
# | steps                   | 396954   |
# --------------------------------------
# --------------------------------------
# | episodes                | 346      |
# | exploration (current)   | 91.496 % |
# | exploration (target)    | 92.442 % |
# | mean 100 episode reward | 4.725    |
# | steps                   | 397782   |
# --------------------------------------
# --------------------------------------
# | episodes                | 347      |
# | exploration (current)   | 90.693 % |
# | exploration (target)    | 92.438 % |
# | mean 100 episode reward | 4.745    |
# | steps                   | 397980   |
# --------------------------------------
# --------------------------------------
# | episodes                | 348      |
# | exploration (current)   | 84.006 % |
# | exploration (target)    | 92.394 % |
# | mean 100 episode reward | 4.785    |
# | steps                   | 400339   |
# --------------------------------------
# --------------------------------------
# | episodes                | 349      |
# | exploration (current)   | 88.132 % |
# | exploration (target)    | 92.364 % |
# | mean 100 episode reward | 4.765    |
# | steps                   | 401910   |
# --------------------------------------
# step: 402259 IPS: 19.81
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 350      |
# | exploration (current)   | 90.733 % |
# | exploration (target)    | 92.357 % |
# | mean 100 episode reward | 4.595    |
# | steps                   | 402258   |
# --------------------------------------
# --------------------------------------
# | episodes                | 351      |
# | exploration (current)   | 76.337 % |
# | exploration (target)    | 92.356 % |
# | mean 100 episode reward | 4.615    |
# | steps                   | 402311   |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_142_steps_402259_episode_350.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_142_steps_402259_episode_350.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_142_steps_402259_episode_350.npy
# --------------------------------------
# | episodes                | 352      |
# | exploration (current)   | 91.728 % |
# | exploration (target)    | 92.353 % |
# | mean 100 episode reward | 4.615    |
# | steps                   | 402481   |
# --------------------------------------
# --------------------------------------
# | episodes                | 353      |
# | exploration (current)   | 95.796 % |
# | exploration (target)    | 92.345 % |
# | mean 100 episode reward | 4.595    |
# | steps                   | 402919   |
# --------------------------------------
# --------------------------------------
# | episodes                | 354      |
# | exploration (current)   | 84.048 % |
# | exploration (target)    | 92.341 % |
# | mean 100 episode reward | 4.575    |
# | steps                   | 403100   |
# --------------------------------------
# --------------------------------------
# | episodes                | 355      |
# | exploration (current)   | 92.239 % |
# | exploration (target)    | 92.295 % |
# | mean 100 episode reward | 4.710    |
# | steps                   | 405517   |
# --------------------------------------
# --------------------------------------
# | episodes                | 356      |
# | exploration (current)   | 80.939 % |
# | exploration (target)    | 92.249 % |
# | mean 100 episode reward | 4.665    |
# | steps                   | 407947   |
# --------------------------------------
# --------------------------------------
# | episodes                | 357      |
# | exploration (current)   | 95.235 % |
# | exploration (target)    | 92.217 % |
# | mean 100 episode reward | 4.685    |
# | steps                   | 409649   |
# --------------------------------------
# --------------------------------------
# | episodes                | 358      |
# | exploration (current)   | 93.233 % |
# | exploration (target)    | 92.212 % |
# | mean 100 episode reward | 4.545    |
# | steps                   | 409877   |
# --------------------------------------
# --------------------------------------
# | episodes                | 359      |
# | exploration (current)   | 91.642 % |
# | exploration (target)    | 92.170 % |
# | mean 100 episode reward | 4.690    |
# | steps                   | 412089   |
# --------------------------------------
# step: 413470 IPS: 19.63
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 360      |
# | exploration (current)   | 87.078 % |
# | exploration (target)    | 92.144 % |
# | mean 100 episode reward | 4.730    |
# | steps                   | 413469   |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0004.000_distance_777_steps_413470_episode_360.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0004.000_distance_777_steps_413470_episode_360.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0004.000_distance_777_steps_413470_episode_360.npy
# --------------------------------------
# | episodes                | 361      |
# | exploration (current)   | 91.057 % |
# | exploration (target)    | 92.098 % |
# | mean 100 episode reward | 4.935    |
# | steps                   | 415899   |
# --------------------------------------
# --------------------------------------
# | episodes                | 362      |
# | exploration (current)   | 80.904 % |
# | exploration (target)    | 92.071 % |
# | mean 100 episode reward | 4.975    |
# | steps                   | 417335   |
# --------------------------------------
# --------------------------------------
# | episodes                | 363      |
# | exploration (current)   | 82.910 % |
# | exploration (target)    | 92.025 % |
# | mean 100 episode reward | 4.995    |
# | steps                   | 419737   |
# --------------------------------------
# --------------------------------------
# | episodes                | 364      |
# | exploration (current)   | 90.644 % |
# | exploration (target)    | 91.979 % |
# | mean 100 episode reward | 5.050    |
# | steps                   | 422167   |
# --------------------------------------
# --------------------------------------
# | episodes                | 365      |
# | exploration (current)   | 86.337 % |
# | exploration (target)    | 91.941 % |
# | mean 100 episode reward | 5.040    |
# | steps                   | 424137   |
# --------------------------------------
# --------------------------------------
# | episodes                | 366      |
# | exploration (current)   | 81.348 % |
# | exploration (target)    | 91.900 % |
# | mean 100 episode reward | 5.065    |
# | steps                   | 426329   |
# --------------------------------------
# --------------------------------------
# | episodes                | 367      |
# | exploration (current)   | 92.231 % |
# | exploration (target)    | 91.865 % |
# | mean 100 episode reward | 5.055    |
# | steps                   | 428159   |
# --------------------------------------
# --------------------------------------
# | episodes                | 368      |
# | exploration (current)   | 75.626 % |
# | exploration (target)    | 91.862 % |
# | mean 100 episode reward | 5.055    |
# | steps                   | 428323   |
# --------------------------------------
# --------------------------------------
# | episodes                | 369      |
# | exploration (current)   | 80.648 % |
# | exploration (target)    | 91.860 % |
# | mean 100 episode reward | 5.015    |
# | steps                   | 428434   |
# --------------------------------------
# step: 428581 IPS: 19.52
# [renderer] preparing next video... 0 in the queue
# --------------------------------------
# | episodes                | 370      |
# | exploration (current)   | 90.442 % |
# | exploration (target)    | 91.857 % |
# | mean 100 episode reward | 4.830    |
# | steps                   | 428580   |
# --------------------------------------
# created video pytorch_results/07_Jan_2019_04_22_34/videos/score_0000.000_distance_153_steps_428581_episode_370.mp4
# created visits numpy file pytorch_results/07_Jan_2019_04_22_34/visits/score_0000.000_distance_153_steps_428581_episode_370.npy
# created coordinates numpy file pytorch_results/07_Jan_2019_04_22_34/coords/score_0000.000_distance_153_steps_428581_episode_370.npy
# --------------------------------------
# | episodes                | 371      |
# | exploration (current)   | 95.005 % |
# | exploration (target)    | 91.818 % |
# | mean 100 episode reward | 4.985    |
# | steps                   | 430611   |
# --------------------------------------
